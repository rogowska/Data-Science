# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Exercise 1
# a) Load house sales data from file kc_house_data.csv, print first records.
# b) Print the variable list. Select categorical and numerical variables.
# c) Compute basic statistics of numerical variables. Are all of them meaningful?

# %%
#a)
#Your code:

from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/kc_house_data.csv')
df.head()

#Hint: read_csv(), head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# ...

# %%
#b)

print(df.columns)

house_categorical_df = df[['id', 'date', 'waterfront', 'view', 'condition', 'grade', 'yr_built', 'yr_renovated', 'zipcode']]
#id and zipcode are just an identificators - has no numerical value, waterfront's 1 or 0 has same meaning as true or false,
#view, condition and grade represented by numbers categorize the state of the building, yr_build and yr_renovated are just a dates,

house_numerical_df = df[['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'sqft_above', 'sqft_basement', 'lat', 'long', 'sqft_living15', 'sqft_lot15']]
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
#c)
#Your code:

house_numerical_df.describe()

#Not all of them are meaningful. Count category (which counts number of non-NA/null occurances) seems unreasonable since all the fileds are filled in each record.
#For the floor category, percentages fields seem a little unreasonable since the count of floors varies from 1-3.
#Standard deviation doesnt find its use in the number of bedrooms, bathrooms and floor categories.

#Hint: Function describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.370842      2.114757   2079.899736  1.510697e+04
# std    3.671272e+05      0.930062      0.770163    918.440897  4.142051e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    sqft_above  sqft_basement           lat          long  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       1.494309   1788.390691     291.509045     47.560053   -122.213896
# ...

# %% [markdown]
# ## Exercise 2
# Using scatter plot:
# a) Show the relation of square footage and price.
# b) Check how price is influenced by apartment's grade. Find other variables correlated with price.
# c) Check how good apartments are distributed over the city. First, plot zipcode versus price. Then, use apartments coordinates (longitude and lattitude) in order to show where apartments of good grade are located.

# %%
#a)
#Your code:
plt.figure(figsize = (15,10))
plt.scatter(df['sqft_living'], df['price'])
plt.xlabel("Square footage")
plt.ylabel("Price")
plt.show()

#We can notice a relation between square footage and price - the bigger square footage is, the price is higher. This relation is nearly linear.

# %%
#b)
#Your code:
plt.figure(figsize = (15,10))
plt.scatter(df['grade'], df['price'])
plt.xlabel("Grade")
plt.ylabel("Price")
plt.show()

#We can notice that more expensive houses are better graded, and the ones poorly graded are mostly cheap.

# %%
#c)
#Your code:
plt.figure(figsize = (15,10))
plt.scatter(df['zipcode'], df['price'])
plt.xlabel("Zipcode")
plt.ylabel("Price")
plt.show()

#We can notice that price isnt noticeably corelated with the zipcode.

# %%
#Your code:
plt.figure(figsize = (15,10))
plt.scatter(df.long, df.lat, c=df.grade, cmap='viridis')
plt.colorbar(label = 'grade')
plt.xlabel("Longitude")
plt.ylabel("Lattitude")
plt.show()

#We can notice that the best graded houses are in the centre of the map.

# %% [markdown]
# ## Exercise 3
# a) Create boxplot of apartment's grade versus it's price. Compare with plot 2b).
# b) Create mosaic plot of any two categorical variables.

# %%
#a)
#Your code:
box_df = df[["grade", "price"]]
box_df.boxplot(by="grade")


#The boxplot seem to be more accurate for bigger data sets, and scatter plot presents data nicely for small data sets.
# Out:
# <Axes: title={'center': 'price'}, xlabel='[grade]'>

# %%
#b)
from statsmodels.graphics.mosaicplot import mosaic

#Your code:
mosaic(df, ['grade', 'condition'], title='Grade to condition')
# Out:
# (<Figure size 640x480 with 3 Axes>,
#  {('7', '3'): (0.0, 0.0, 0.3938738818549393, 0.5751176460246487),
#   ('7', '5'): (0.0,
#    0.5784071197088592,
#    0.3938738818549393,
#    0.09153095130655943),
#   ('7', '4'): (0.0,
#    0.6732275446996292,
#    0.3938738818549393,
#    0.31129313931750663),
#   ('7', '1'): (0.0,
#    0.9878101577013462,
#    0.3938738818549393,
#    0.0006592865640328134),
#   ('7', '2'): (0.0,
#    0.9917589179495896,
#    0.3938738818549393,
#    0.008241082050410495),
#   ('6', '3'): (0.3986132183478303,
#    0.0,
#    0.0893792418684296,
#    0.5011685863333506),
#   ('6', '5'): (0.3986132183478303,
#    0.5044580600175611,
#    0.0893792418684296,
#    0.12008677237745984),
#   ('6', '4'): (0.3986132183478303,
#    0.6278343060792315,
#    0.0893792418684296,
#    0.3316912866070968),
#   ('6', '1'): (0.3986132183478303,
#    0.9628150663705388,
#    0.0893792418684296,
#    0.005326429419967985),
#   ('6', '2'): (0.3986132183478303,
# ...

# %% [markdown]
# ## Exercise 4
# "I am interested in the house with 3 bedrooms, 2 bathrooms and 2 floors"
# a) Compute the basic statistics of apartments fulfilling above constraints.
# b) Distinct accepted apartments on any of previously created plots.
# c) Find such apartments with best price to footage ratio.

# %%
#a)
#Your code:
chosen = df.loc[(df['bedrooms'] == 3) & (df['bathrooms'] == 2) & (df['floors'] == 2)]
chosen.describe()

#Hint: pandas.DataFrame.loc
# Out:
#                  id         price  bedrooms  bathrooms  sqft_living  \
# count  1.540000e+02  1.540000e+02     154.0      154.0   154.000000
# mean   4.397177e+09  5.144986e+05       3.0        2.0  1850.279221
# std    2.849813e+09  2.497661e+05       0.0        0.0   547.585413
# min    7.600057e+06  2.090000e+05       3.0        2.0  1020.000000
# 25%    2.060901e+09  3.769750e+05       3.0        2.0  1452.500000
# 50%    3.630010e+09  4.640000e+05       3.0        2.0  1700.000000
# 75%    7.184074e+09  5.894625e+05       3.0        2.0  2127.500000
# max    9.829200e+09  1.755000e+06       3.0        2.0  3650.000000
#
#             sqft_lot  floors  waterfront        view   condition       grade  \
# count     154.000000   154.0  154.000000  154.000000  154.000000  154.000000
# mean    23678.948052     2.0    0.006494    0.357143    3.435065    7.551948
# std     83324.024708     0.0    0.080582    0.919495    0.713322    0.832684
# ...

# %%
#b)
#Your code:
plt.figure(figsize = (15,10))
plt.scatter(df['sqft_living'], df['price'])
plt.scatter(chosen['sqft_living'], chosen['price'])
plt.xlabel("Square footage")
plt.ylabel("Price")
plt.show()

# %%
#c)
#Your code:
chosen['best_ratio'] = chosen['price'] / df['sqft_living']
chosen.sort_values('best_ratio', ascending = True)

#Hint: .loc, .sort_values(), .index
# Out:
# <ipython-input-94-5c739d183b8b>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chosen['best_ratio'] = chosen['price'] / df['sqft_living']
#                id             date      price  bedrooms  bathrooms  \
# 9704   7452500565  20140829T000000   260000.0         3        2.0
# 11258  7937600262  20140710T000000   379900.0         3        2.0
# 19880  3832050860  20150319T000000   210000.0         3        2.0
# 16014  5104450440  20141113T000000   252500.0         3        2.0
# 20906  3355400242  20141028T000000   274900.0         3        2.0
# ...           ...              ...        ...       ...        ...
# 14379  9829200325  20140617T000000   765000.0         3        2.0
# ...
